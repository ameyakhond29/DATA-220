# %%
import sympy as sp

x = sp.symbols('x')

f = 2*x**3 - 9*x + 4
g = 12*x + 3


sp.plot(f, g,  title="my first graph", legend=True)

# %%
import sympy as sp

x, y = sp.symbols('x y')

z = 3*x**2 - 2*y**2

z_sub = z.subs(y, 1)  

sp.plot(z_sub)
